# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from torchvision.utils import save_image

transform = transforms.Compose([
    transforms.ToTensor(),
    #transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

root = '/root/data/MNIST/'

bs = 100
# MNIST Dataset
train_dataset = datasets.MNIST(root=root, train=True, transform=transforms.ToTensor(), download=False)
test_dataset = datasets.MNIST(root=root, train=False, transform=transforms.ToTensor(), download=False)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=bs, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=bs, shuffle=False)

# %%
class CVAE(nn.Module):

    def __init__(self, condi_dim, channels, latent_dim) -> None:
        super().__init__()

        # encoder
        pre_channel = 1
        modules = []
        img_length = 28
        
        for i in range(len(channels)-1):
            modules.append(
                nn.Sequential(
                    nn.Conv2d(pre_channel,
                              channels[i+1],
                              kernel_size=3,
                              stride=2,
                              padding=1),
                    nn.BatchNorm2d(channels[i+1]),
                    nn.ReLU()
                )
            )
            pre_channel = channels[i+1]
            img_length = (img_length-1)//2+1
        
        self.encoder_projection = nn.Sequential(
                nn.Linear(pre_channel * img_length * img_length + condi_dim, pre_channel * img_length * img_length),
                nn.ReLU()
        )
        
        self.encoder = nn.Sequential(*modules)
        self.mean_linear = nn.Linear(pre_channel * img_length * img_length,
                                     latent_dim)
        self.var_linear = nn.Linear(pre_channel * img_length * img_length,
                                    latent_dim)
        self.latent_dim = latent_dim
        
        # decoder
        modules = []
        self.decoder_projection = nn.Linear(
            latent_dim + condi_dim, pre_channel * img_length * img_length)
        self.decoder_input_chw = (pre_channel, img_length, img_length)

        for i in range(len(channels)-1):
            if(i == 0):
                modules.append(
                    nn.Sequential(
                        nn.ConvTranspose2d(channels[len(channels)-i-1],
                                           channels[len(channels)-i-2],
                                           kernel_size=3,
                                           stride=2,
                                           padding=1,
                                           output_padding=0),
                        nn.BatchNorm2d(channels[len(channels)-i-2]),
                        nn.ReLU()
                    )
                )
            else:
                modules.append(
                    nn.Sequential(
                        nn.ConvTranspose2d(channels[len(channels)-i-1],
                                           channels[len(channels)-i-2],
                                           kernel_size=3,
                                           stride=2,
                                           padding=1,
                                           output_padding=1),
                        nn.BatchNorm2d(channels[len(channels)-i-2]),
                        nn.ReLU()
                    )
                )
        self.decoder_layers = nn.Sequential(*modules)
        
    def decoder(self, z, c):
        z = torch.cat([z, c], dim = 1)
        z = self.decoder_projection(z)
        z = torch.reshape(z, (-1, *self.decoder_input_chw))
        decoded = self.decoder_layers(z)
        return decoded

    def forward(self, x, c):
        x = self.encoder(x)
        x = torch.flatten(x, 1)
        x = torch.cat([x, c], dim = 1)
        encoded = self.encoder_projection(x)
        mean = self.mean_linear(encoded)
        logvar = self.var_linear(encoded)
        eps = torch.randn_like(logvar)
        std = torch.exp(logvar / 2)
        z = eps * std + mean
        decoded = self.decoder(z, c)
        return decoded, mean, logvar

# %%
from time import time
import numpy as np

n_epochs = 2000
learning_rate = 1e-2
kl_weight = 2e-5
num_class = 10

def one_hot_encode(labels, num_classes):
    one_hot_labels = np.zeros((len(labels), num_classes))
    one_hot_labels[np.arange(len(labels)), labels] = 1
    return one_hot_labels.tolist()

def elbo_loss(x, x_hat, mean, logvar):
    recons_loss = F.mse_loss(x_hat, x)
    kl_loss = -0.5 * torch.sum(1 + logvar - mean**2 - torch.exp(logvar))
    loss = (recons_loss + kl_loss * kl_weight)/len(x)
    return loss

def reconst_loss(x, x_hat):
    return F.mse_loss(x_hat, x) / len(x)

def kl_loss(mean, logvar):
    return -0.5 * torch.sum(1 + logvar - mean**2 - torch.exp(logvar)) / len(mean)

def train(device, model):
    optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate)
    begin_time = time()
    # train
    with open('./base_loss.txt', 'w') as file:
        for i in range(n_epochs):
            for batch_idx, (x, label) in enumerate(train_loader):
                x = x.to(device)
                label = one_hot_encode(label, num_classes = num_class)
                label = torch.tensor(label)
                label = label.to(device)
                x_hat, mean, logvar = model(x, label)
                loss = elbo_loss(x, x_hat, mean, logvar)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
            # estimate loss
            model.eval()
            with torch.no_grad():
                each_epoch = 10
                n_samples = 100
                #train
                indices = torch.randperm(len(train_dataset))[:n_samples]
                x = torch.stack([train_dataset[i][0] for i in indices]).to(device)
                label = one_hot_encode([train_dataset[i][1] for i in indices], num_classes = num_class)
                label = torch.tensor(label).to(device)
                x_hat, mean, logvar = model(x, label)
                loss = elbo_loss(x, x_hat, mean, logvar)
                loss_recons = reconst_loss(x, x_hat)
                loss_kl = kl_loss(mean, logvar)
                if(i % each_epoch == 0):
                    print('====> Epoch: {} elbo loss: {:.7f}'.format(i, loss))
                    print('====> Epoch: {} reconst loss: {:.7f}'.format(i, loss_recons))
                    print('====> Epoch: {} kl loss: {:.7f}'.format(i, loss_kl))
                file.write(str(loss.item()) + ' ' + str(loss_recons.item()) + ' ' + str(loss_kl.item()) + ' ')
                #test
                indices = torch.randperm(len(test_dataset))[:n_samples]
                x = torch.stack([test_dataset[i][0] for i in indices]).to(device)
                label = one_hot_encode([test_dataset[i][1] for i in indices], num_classes = num_class)
                label = torch.tensor(label).to(device)
                x_hat, mean, logvar = model(x, label)
                loss = elbo_loss(x, x_hat, mean, logvar)
                loss_recons = reconst_loss(x, x_hat)
                loss_kl = kl_loss(mean, logvar)
                if(i % each_epoch == 0):
                    print('====> Epoch: {} elbo loss: {:.7f}'.format(i, loss))
                    print('====> Epoch: {} reconst loss: {:.7f}'.format(i, loss_recons))
                    print('====> Epoch: {} kl loss: {:.7f}'.format(i, loss_kl))
                file.write(str(loss.item()) + ' ' + str(loss_recons.item()) + ' ' + str(loss_kl.item()) + '\n')
            
            #time
            if(i % each_epoch == 0):
                training_time = time() - begin_time
                minute = int(training_time // 60)
                second = int(training_time % 60)
                print(f'time loss {minute}:{second}')
        
        torch.save(model, './vae_model.pth')
        
    tot_training_time = time() - begin_time
    minute = int(tot_training_time // 60)
    second = int(tot_training_time % 60)
    print(f'total time loss {minute}:{second}')

def initialize_parameters(model):
    for param in model.parameters():
        param.data.normal_(mean=0, std=0.01)

# %%
def main():
    device = 'cuda:0'

    model = CVAE(condi_dim = num_class, channels = [1, 500, 500, 500], latent_dim = 5).to(device)
    initialize_parameters(model)

    train(device, model)

if __name__ == '__main__':
    main()
# Out:
# ====> Epoch: 0 elbo loss: 0.0004707
# ====> Epoch: 0 reconst loss: 0.0004191
# ====> Epoch: 0 kl loss: 2.5769122
# ====> Epoch: 0 elbo loss: 0.0004295
# ====> Epoch: 0 reconst loss: 0.0003813
# ====> Epoch: 0 kl loss: 2.4102268
# time loss 0:10
# ====> Epoch: 10 elbo loss: 0.0003679
# ====> Epoch: 10 reconst loss: 0.0002710
# ====> Epoch: 10 kl loss: 4.8476725
# ====> Epoch: 10 elbo loss: 0.0003811
# ====> Epoch: 10 reconst loss: 0.0002837
# ====> Epoch: 10 kl loss: 4.8731079
# time loss 1:53
# ====> Epoch: 20 elbo loss: 0.0003702
# ====> Epoch: 20 reconst loss: 0.0002633
# ====> Epoch: 20 kl loss: 5.3485007
# ====> Epoch: 20 elbo loss: 0.0003411
# ====> Epoch: 20 reconst loss: 0.0002363
# ====> Epoch: 20 kl loss: 5.2434974
# time loss 3:37
# ====> Epoch: 30 elbo loss: 0.0003577
# ====> Epoch: 30 reconst loss: 0.0002505
# ====> Epoch: 30 kl loss: 5.3600159
# ====> Epoch: 30 elbo loss: 0.0003373
# ====> Epoch: 30 reconst loss: 0.0002308
# ====> Epoch: 30 kl loss: 5.3244848
# time loss 5:20
# ====> Epoch: 40 elbo loss: 0.0003300
# ====> Epoch: 40 reconst loss: 0.0002256
# ====> Epoch: 40 kl loss: 5.2182665
# ====> Epoch: 40 elbo loss: 0.0003542
# ====> Epoch: 40 reconst loss: 0.0002453
# ====> Epoch: 40 kl loss: 5.4451990
# time loss 7:3
# ====> Epoch: 50 elbo loss: 0.0003690
# ====> Epoch: 50 reconst loss: 0.0002521
# ====> Epoch: 50 kl loss: 5.8457446
# ====> Epoch: 50 elbo loss: 0.0003512
# ====> Epoch: 50 reconst loss: 0.0002418
# ====> Epoch: 50 kl loss: 5.4676642
# time loss 8:47
# ====> Epoch: 60 elbo loss: 0.0003570
# ====> Epoch: 60 reconst loss: 0.0002446
# ====> Epoch: 60 kl loss: 5.6206727
# ====> Epoch: 60 elbo loss: 0.0003337
# ====> Epoch: 60 reconst loss: 0.0002296
# ====> Epoch: 60 kl loss: 5.2061968
# time loss 10:31
# ====> Epoch: 70 elbo loss: 0.0003288
# ====> Epoch: 70 reconst loss: 0.0002160
# ====> Epoch: 70 kl loss: 5.6390123
# ====> Epoch: 70 elbo loss: 0.0003429
# ====> Epoch: 70 reconst loss: 0.0002319
# ====> Epoch: 70 kl loss: 5.5520658
# time loss 12:16
# ====> Epoch: 80 elbo loss: 0.0003344
# ====> Epoch: 80 reconst loss: 0.0002230
# ====> Epoch: 80 kl loss: 5.5696750
# ====> Epoch: 80 elbo loss: 0.0003476
# ====> Epoch: 80 reconst loss: 0.0002376
# ====> Epoch: 80 kl loss: 5.5020456
# time loss 14:1
# ====> Epoch: 90 elbo loss: 0.0003575
# ====> Epoch: 90 reconst loss: 0.0002404
# ====> Epoch: 90 kl loss: 5.8571644
# ====> Epoch: 90 elbo loss: 0.0003470
# ====> Epoch: 90 reconst loss: 0.0002360
# ====> Epoch: 90 kl loss: 5.5479770
# time loss 15:46
# ====> Epoch: 100 elbo loss: 0.0003271
# ====> Epoch: 100 reconst loss: 0.0002152
# ====> Epoch: 100 kl loss: 5.5948539
# ====> Epoch: 100 elbo loss: 0.0003503
# ====> Epoch: 100 reconst loss: 0.0002376
# ====> Epoch: 100 kl loss: 5.6394601
# time loss 17:23
# ====> Epoch: 110 elbo loss: 0.0003624
# ====> Epoch: 110 reconst loss: 0.0002455
# ====> Epoch: 110 kl loss: 5.8418260
# ====> Epoch: 110 elbo loss: 0.0003389
# ====> Epoch: 110 reconst loss: 0.0002254
# ====> Epoch: 110 kl loss: 5.6736460
# time loss 19:8
# ====> Epoch: 120 elbo loss: 0.0003253
# ====> Epoch: 120 reconst loss: 0.0002134
# ====> Epoch: 120 kl loss: 5.5917192
# ====> Epoch: 120 elbo loss: 0.0003465
# ====> Epoch: 120 reconst loss: 0.0002312
# ====> Epoch: 120 kl loss: 5.7611923
# time loss 20:53
# ====> Epoch: 130 elbo loss: 0.0003375
# ====> Epoch: 130 reconst loss: 0.0002258
# ====> Epoch: 130 kl loss: 5.5873132
# ====> Epoch: 130 elbo loss: 0.0003689
# ====> Epoch: 130 reconst loss: 0.0002515
# ====> Epoch: 130 kl loss: 5.8696408
# time loss 22:36
# ====> Epoch: 140 elbo loss: 0.0003423
# ====> Epoch: 140 reconst loss: 0.0002264
# ====> Epoch: 140 kl loss: 5.7951498
# ====> Epoch: 140 elbo loss: 0.0003509
# ====> Epoch: 140 reconst loss: 0.0002396
# ====> Epoch: 140 kl loss: 5.5624852
# time loss 24:21
# ====> Epoch: 150 elbo loss: 0.0003502
# ====> Epoch: 150 reconst loss: 0.0002356
# ====> Epoch: 150 kl loss: 5.7326956
# ====> Epoch: 150 elbo loss: 0.0003397
# ====> Epoch: 150 reconst loss: 0.0002273
# ====> Epoch: 150 kl loss: 5.6197429
# time loss 26:6
# ====> Epoch: 160 elbo loss: 0.0003446
# ====> Epoch: 160 reconst loss: 0.0002311
# ====> Epoch: 160 kl loss: 5.6752539
# ====> Epoch: 160 elbo loss: 0.0003552
# ====> Epoch: 160 reconst loss: 0.0002471
# ====> Epoch: 160 kl loss: 5.4085002
# time loss 27:51
# ====> Epoch: 170 elbo loss: 0.0003366
# ====> Epoch: 170 reconst loss: 0.0002249
# ====> Epoch: 170 kl loss: 5.5888352
# ====> Epoch: 170 elbo loss: 0.0003213
# ====> Epoch: 170 reconst loss: 0.0002135
# ====> Epoch: 170 kl loss: 5.3892431
# time loss 29:36
# ====> Epoch: 180 elbo loss: 0.0003452
# ====> Epoch: 180 reconst loss: 0.0002266
# ====> Epoch: 180 kl loss: 5.9266648
# ====> Epoch: 180 elbo loss: 0.0003500
# ====> Epoch: 180 reconst loss: 0.0002355
# ====> Epoch: 180 kl loss: 5.7257657
# time loss 31:22
# ====> Epoch: 190 elbo loss: 0.0003457
# ====> Epoch: 190 reconst loss: 0.0002279
# ====> Epoch: 190 kl loss: 5.8931627
# ====> Epoch: 190 elbo loss: 0.0003591
# ====> Epoch: 190 reconst loss: 0.0002383
# ====> Epoch: 190 kl loss: 6.0383606
# time loss 33:7
# ====> Epoch: 200 elbo loss: 0.0003606
# ====> Epoch: 200 reconst loss: 0.0002375
# ====> Epoch: 200 kl loss: 6.1551847
# ====> Epoch: 200 elbo loss: 0.0003495
# ====> Epoch: 200 reconst loss: 0.0002354
# ====> Epoch: 200 kl loss: 5.7082739
# time loss 34:52
# ====> Epoch: 210 elbo loss: 0.0003353
# ====> Epoch: 210 reconst loss: 0.0002207
# ====> Epoch: 210 kl loss: 5.7308812
# ====> Epoch: 210 elbo loss: 0.0003426
# ====> Epoch: 210 reconst loss: 0.0002316
# ====> Epoch: 210 kl loss: 5.5495248
# time loss 36:36
# ====> Epoch: 220 elbo loss: 0.0003332
# ====> Epoch: 220 reconst loss: 0.0002209
# ====> Epoch: 220 kl loss: 5.6170030
# ====> Epoch: 220 elbo loss: 0.0003409
# ====> Epoch: 220 reconst loss: 0.0002284
# ====> Epoch: 220 kl loss: 5.6251307
# time loss 38:21
# ====> Epoch: 230 elbo loss: 0.0003449
# ====> Epoch: 230 reconst loss: 0.0002302
# ====> Epoch: 230 kl loss: 5.7311320
# ====> Epoch: 230 elbo loss: 0.0003389
# ====> Epoch: 230 reconst loss: 0.0002226
# ====> Epoch: 230 kl loss: 5.8160424
# time loss 40:6
# ====> Epoch: 240 elbo loss: 0.0003112
# ====> Epoch: 240 reconst loss: 0.0001993
# ====> Epoch: 240 kl loss: 5.5952702
# ====> Epoch: 240 elbo loss: 0.0003434
# ====> Epoch: 240 reconst loss: 0.0002275
# ====> Epoch: 240 kl loss: 5.7973423
# time loss 41:49
# ====> Epoch: 250 elbo loss: 0.0003284
# ====> Epoch: 250 reconst loss: 0.0002150
# ====> Epoch: 250 kl loss: 5.6667142
# ====> Epoch: 250 elbo loss: 0.0003415
# ====> Epoch: 250 reconst loss: 0.0002235
# ====> Epoch: 250 kl loss: 5.8977380
# time loss 43:34
# ====> Epoch: 260 elbo loss: 0.0003449
# ====> Epoch: 260 reconst loss: 0.0002285
# ====> Epoch: 260 kl loss: 5.8227806
# ====> Epoch: 260 elbo loss: 0.0003410
# ====> Epoch: 260 reconst loss: 0.0002283
# ====> Epoch: 260 kl loss: 5.6338830
# time loss 45:19
# ====> Epoch: 270 elbo loss: 0.0003493
# ====> Epoch: 270 reconst loss: 0.0002354
# ====> Epoch: 270 kl loss: 5.6949058
# ====> Epoch: 270 elbo loss: 0.0003284
# ====> Epoch: 270 reconst loss: 0.0002164
# ====> Epoch: 270 kl loss: 5.6018028
# time loss 46:56
# ====> Epoch: 280 elbo loss: 0.0003369
# ====> Epoch: 280 reconst loss: 0.0002190
# ====> Epoch: 280 kl loss: 5.8938661
# ====> Epoch: 280 elbo loss: 0.0003433
# ====> Epoch: 280 reconst loss: 0.0002267
# ====> Epoch: 280 kl loss: 5.8309250
# time loss 48:31
# ====> Epoch: 290 elbo loss: 0.0003429
# ====> Epoch: 290 reconst loss: 0.0002212
# ====> Epoch: 290 kl loss: 6.0827489
# ====> Epoch: 290 elbo loss: 0.0003684
# ====> Epoch: 290 reconst loss: 0.0002509
# ====> Epoch: 290 kl loss: 5.8736191
# time loss 50:16
# ====> Epoch: 300 elbo loss: 0.0003172
# ====> Epoch: 300 reconst loss: 0.0002057
# ====> Epoch: 300 kl loss: 5.5761595
# ====> Epoch: 300 elbo loss: 0.0003533
# ====> Epoch: 300 reconst loss: 0.0002360
# ====> Epoch: 300 kl loss: 5.8652220
# time loss 52:37
# ====> Epoch: 310 elbo loss: 0.0003337
# ====> Epoch: 310 reconst loss: 0.0002143
# ====> Epoch: 310 kl loss: 5.9732194
# ====> Epoch: 310 elbo loss: 0.0003214
# ====> Epoch: 310 reconst loss: 0.0002041
# ====> Epoch: 310 kl loss: 5.8642368
# time loss 55:20
# ====> Epoch: 320 elbo loss: 0.0003284
# ====> Epoch: 320 reconst loss: 0.0002108
# ====> Epoch: 320 kl loss: 5.8808355
# ====> Epoch: 320 elbo loss: 0.0003533
# ====> Epoch: 320 reconst loss: 0.0002368
# ====> Epoch: 320 kl loss: 5.8224974
# time loss 58:3
# ====> Epoch: 330 elbo loss: 0.0003513
# ====> Epoch: 330 reconst loss: 0.0002343
# ====> Epoch: 330 kl loss: 5.8492823
# ====> Epoch: 330 elbo loss: 0.0003389
# ====> Epoch: 330 reconst loss: 0.0002262
# ====> Epoch: 330 kl loss: 5.6372123
# time loss 60:46
# ====> Epoch: 340 elbo loss: 0.0003250
# ====> Epoch: 340 reconst loss: 0.0002107
# ====> Epoch: 340 kl loss: 5.7137609
# ====> Epoch: 340 elbo loss: 0.0003454
# ====> Epoch: 340 reconst loss: 0.0002305
# ====> Epoch: 340 kl loss: 5.7451620
# time loss 63:30
# ====> Epoch: 350 elbo loss: 0.0003403
# ====> Epoch: 350 reconst loss: 0.0002222
# ====> Epoch: 350 kl loss: 5.9033561
# ====> Epoch: 350 elbo loss: 0.0003391
# ====> Epoch: 350 reconst loss: 0.0002250
# ====> Epoch: 350 kl loss: 5.7049046
# time loss 66:13
# ====> Epoch: 360 elbo loss: 0.0003267
# ====> Epoch: 360 reconst loss: 0.0002125
# ====> Epoch: 360 kl loss: 5.7070470
# ====> Epoch: 360 elbo loss: 0.0003505
# ====> Epoch: 360 reconst loss: 0.0002330
# ====> Epoch: 360 kl loss: 5.8744993
# time loss 68:56
# ====> Epoch: 370 elbo loss: 0.0003386
# ====> Epoch: 370 reconst loss: 0.0002180
# ====> Epoch: 370 kl loss: 6.0290284
# ====> Epoch: 370 elbo loss: 0.0003513
# ====> Epoch: 370 reconst loss: 0.0002339
# ====> Epoch: 370 kl loss: 5.8692727
# time loss 71:39
# ====> Epoch: 380 elbo loss: 0.0003079
# ====> Epoch: 380 reconst loss: 0.0001938
# ====> Epoch: 380 kl loss: 5.7025781
# ====> Epoch: 380 elbo loss: 0.0003427
# ====> Epoch: 380 reconst loss: 0.0002304
# ====> Epoch: 380 kl loss: 5.6109986
# time loss 74:22
# ====> Epoch: 390 elbo loss: 0.0003212
# ====> Epoch: 390 reconst loss: 0.0002084
# ====> Epoch: 390 kl loss: 5.6391854
# ====> Epoch: 390 elbo loss: 0.0003552
# ====> Epoch: 390 reconst loss: 0.0002397
# ====> Epoch: 390 kl loss: 5.7760992
# time loss 77:6
# ====> Epoch: 400 elbo loss: 0.0003213
# ====> Epoch: 400 reconst loss: 0.0002050
# ====> Epoch: 400 kl loss: 5.8149462
# ====> Epoch: 400 elbo loss: 0.0003383
# ====> Epoch: 400 reconst loss: 0.0002209
# ====> Epoch: 400 kl loss: 5.8724566
# time loss 79:49
# ====> Epoch: 410 elbo loss: 0.0003253
# ====> Epoch: 410 reconst loss: 0.0002148
# ====> Epoch: 410 kl loss: 5.5235243
# ====> Epoch: 410 elbo loss: 0.0003399
# ====> Epoch: 410 reconst loss: 0.0002230
# ====> Epoch: 410 kl loss: 5.8463931
# time loss 82:32
# ====> Epoch: 420 elbo loss: 0.0003469
# ====> Epoch: 420 reconst loss: 0.0002259
# ====> Epoch: 420 kl loss: 6.0524096
# ====> Epoch: 420 elbo loss: 0.0003489
# ====> Epoch: 420 reconst loss: 0.0002326
# ====> Epoch: 420 kl loss: 5.8175344
# time loss 85:15
# ====> Epoch: 430 elbo loss: 0.0003418
# ====> Epoch: 430 reconst loss: 0.0002174
# ====> Epoch: 430 kl loss: 6.2190237
# ====> Epoch: 430 elbo loss: 0.0003634
# ====> Epoch: 430 reconst loss: 0.0002448
# ====> Epoch: 430 kl loss: 5.9313030
# time loss 87:59
# ====> Epoch: 440 elbo loss: 0.0003389
# ====> Epoch: 440 reconst loss: 0.0002208
# ====> Epoch: 440 kl loss: 5.9028568
# ====> Epoch: 440 elbo loss: 0.0003573
# ====> Epoch: 440 reconst loss: 0.0002385
# ====> Epoch: 440 kl loss: 5.9406266
# time loss 90:42
# ====> Epoch: 450 elbo loss: 0.0003440
# ====> Epoch: 450 reconst loss: 0.0002217
# ====> Epoch: 450 kl loss: 6.1124158
# ====> Epoch: 450 elbo loss: 0.0003308
# ====> Epoch: 450 reconst loss: 0.0002175
# ====> Epoch: 450 kl loss: 5.6666017
# time loss 93:25
# ====> Epoch: 460 elbo loss: 0.0003212
# ====> Epoch: 460 reconst loss: 0.0001993
# ====> Epoch: 460 kl loss: 6.0907865
# ====> Epoch: 460 elbo loss: 0.0003524
# ====> Epoch: 460 reconst loss: 0.0002352
# ====> Epoch: 460 kl loss: 5.8567810
# time loss 96:8
# ====> Epoch: 470 elbo loss: 0.0003341
# ====> Epoch: 470 reconst loss: 0.0002140
# ====> Epoch: 470 kl loss: 6.0028100
# ====> Epoch: 470 elbo loss: 0.0003643
# ====> Epoch: 470 reconst loss: 0.0002417
# ====> Epoch: 470 kl loss: 6.1330237
# time loss 98:52
# ====> Epoch: 480 elbo loss: 0.0003153
# ====> Epoch: 480 reconst loss: 0.0001978
# ====> Epoch: 480 kl loss: 5.8750839
# ====> Epoch: 480 elbo loss: 0.0003613
# ====> Epoch: 480 reconst loss: 0.0002412
# ====> Epoch: 480 kl loss: 6.0025730
# time loss 101:35
# ====> Epoch: 490 elbo loss: 0.0003425
# ====> Epoch: 490 reconst loss: 0.0002249
# ====> Epoch: 490 kl loss: 5.8805137
# ====> Epoch: 490 elbo loss: 0.0003346
# ====> Epoch: 490 reconst loss: 0.0002178
# ====> Epoch: 490 kl loss: 5.8372264
# time loss 104:18
# ====> Epoch: 500 elbo loss: 0.0003540
# ====> Epoch: 500 reconst loss: 0.0002310
# ====> Epoch: 500 kl loss: 6.1501093
# ====> Epoch: 500 elbo loss: 0.0003721
# ====> Epoch: 500 reconst loss: 0.0002579
# ====> Epoch: 500 kl loss: 5.7129588
# time loss 107:1
# ====> Epoch: 510 elbo loss: 0.0003160
# ====> Epoch: 510 reconst loss: 0.0002048
# ====> Epoch: 510 kl loss: 5.5600657
# ====> Epoch: 510 elbo loss: 0.0003513
# ====> Epoch: 510 reconst loss: 0.0002383
# ====> Epoch: 510 kl loss: 5.6502318
# time loss 109:44
# ====> Epoch: 520 elbo loss: 0.0003197
# ====> Epoch: 520 reconst loss: 0.0002037
# ====> Epoch: 520 kl loss: 5.8039942
# ====> Epoch: 520 elbo loss: 0.0003589
# ====> Epoch: 520 reconst loss: 0.0002386
# ====> Epoch: 520 kl loss: 6.0175781
# time loss 112:28
# ====> Epoch: 530 elbo loss: 0.0003267
# ====> Epoch: 530 reconst loss: 0.0002080
# ====> Epoch: 530 kl loss: 5.9321380
# ====> Epoch: 530 elbo loss: 0.0003348
# ====> Epoch: 530 reconst loss: 0.0002239
# ====> Epoch: 530 kl loss: 5.5472302
# time loss 115:11
# ====> Epoch: 540 elbo loss: 0.0003330
# ====> Epoch: 540 reconst loss: 0.0002201
# ====> Epoch: 540 kl loss: 5.6463842
# ====> Epoch: 540 elbo loss: 0.0003574
# ====> Epoch: 540 reconst loss: 0.0002390
# ====> Epoch: 540 kl loss: 5.9169493
# time loss 117:54
# ====> Epoch: 550 elbo loss: 0.0003360
# ====> Epoch: 550 reconst loss: 0.0002180
# ====> Epoch: 550 kl loss: 5.8984008
# ====> Epoch: 550 elbo loss: 0.0003511
# ====> Epoch: 550 reconst loss: 0.0002337
# ====> Epoch: 550 kl loss: 5.8691607
# time loss 120:37
# ====> Epoch: 560 elbo loss: 0.0003203
# ====> Epoch: 560 reconst loss: 0.0002056
# ====> Epoch: 560 kl loss: 5.7325854
# ====> Epoch: 560 elbo loss: 0.0003507
# ====> Epoch: 560 reconst loss: 0.0002304
# ====> Epoch: 560 kl loss: 6.0185719
# time loss 123:21
# ====> Epoch: 570 elbo loss: 0.0003551
# ====> Epoch: 570 reconst loss: 0.0002365
# ====> Epoch: 570 kl loss: 5.9267054
# ====> Epoch: 570 elbo loss: 0.0003159
# ====> Epoch: 570 reconst loss: 0.0002049
# ====> Epoch: 570 kl loss: 5.5502381
# time loss 126:4
# ====> Epoch: 580 elbo loss: 0.0003375
# ====> Epoch: 580 reconst loss: 0.0002146
# ====> Epoch: 580 kl loss: 6.1446338
# ====> Epoch: 580 elbo loss: 0.0003439
# ====> Epoch: 580 reconst loss: 0.0002279
# ====> Epoch: 580 kl loss: 5.8012943
# time loss 128:47
# ====> Epoch: 590 elbo loss: 0.0003258
# ====> Epoch: 590 reconst loss: 0.0002074
# ====> Epoch: 590 kl loss: 5.9169135
# ====> Epoch: 590 elbo loss: 0.0003643
# ====> Epoch: 590 reconst loss: 0.0002425
# ====> Epoch: 590 kl loss: 6.0899377
# time loss 131:30
# ====> Epoch: 600 elbo loss: 0.0003153
# ====> Epoch: 600 reconst loss: 0.0001934
# ====> Epoch: 600 kl loss: 6.0977573
# ====> Epoch: 600 elbo loss: 0.0003299
# ====> Epoch: 600 reconst loss: 0.0002155
# ====> Epoch: 600 kl loss: 5.7205067
# time loss 134:14
# ====> Epoch: 610 elbo loss: 0.0003201
# ====> Epoch: 610 reconst loss: 0.0002061
# ====> Epoch: 610 kl loss: 5.7039938
# ====> Epoch: 610 elbo loss: 0.0003266
# ====> Epoch: 610 reconst loss: 0.0002171
# ====> Epoch: 610 kl loss: 5.4758921
# time loss 136:57
# ====> Epoch: 620 elbo loss: 0.0003024
# ====> Epoch: 620 reconst loss: 0.0001845
# ====> Epoch: 620 kl loss: 5.8955569
# ====> Epoch: 620 elbo loss: 0.0003432
# ====> Epoch: 620 reconst loss: 0.0002251
# ====> Epoch: 620 kl loss: 5.9016438
# time loss 139:40
# ====> Epoch: 630 elbo loss: 0.0003343
# ====> Epoch: 630 reconst loss: 0.0002213
# ====> Epoch: 630 kl loss: 5.6477489
# ====> Epoch: 630 elbo loss: 0.0003360
# ====> Epoch: 630 reconst loss: 0.0002196
# ====> Epoch: 630 kl loss: 5.8190031
# time loss 142:23
# ====> Epoch: 640 elbo loss: 0.0003353
# ====> Epoch: 640 reconst loss: 0.0002112
# ====> Epoch: 640 kl loss: 6.2058215
# ====> Epoch: 640 elbo loss: 0.0003690
# ====> Epoch: 640 reconst loss: 0.0002475
# ====> Epoch: 640 kl loss: 6.0724969
# time loss 145:7
# ====> Epoch: 650 elbo loss: 0.0003149
# ====> Epoch: 650 reconst loss: 0.0001949
# ====> Epoch: 650 kl loss: 6.0013037
# ====> Epoch: 650 elbo loss: 0.0003572
# ====> Epoch: 650 reconst loss: 0.0002372
# ====> Epoch: 650 kl loss: 5.9978867
# time loss 147:50
# ====> Epoch: 660 elbo loss: 0.0003268
# ====> Epoch: 660 reconst loss: 0.0002025
# ====> Epoch: 660 kl loss: 6.2174640
# ====> Epoch: 660 elbo loss: 0.0003501
# ====> Epoch: 660 reconst loss: 0.0002319
# ====> Epoch: 660 kl loss: 5.9113669
# time loss 150:33
# ====> Epoch: 670 elbo loss: 0.0003327
# ====> Epoch: 670 reconst loss: 0.0002102
# ====> Epoch: 670 kl loss: 6.1291580
# ====> Epoch: 670 elbo loss: 0.0003489
# ====> Epoch: 670 reconst loss: 0.0002303
# ====> Epoch: 670 kl loss: 5.9330163
# time loss 153:16
# ====> Epoch: 680 elbo loss: 0.0003419
# ====> Epoch: 680 reconst loss: 0.0002198
# ====> Epoch: 680 kl loss: 6.1054230
# ====> Epoch: 680 elbo loss: 0.0003407
# ====> Epoch: 680 reconst loss: 0.0002251
# ====> Epoch: 680 kl loss: 5.7845254
# time loss 155:59
# ====> Epoch: 690 elbo loss: 0.0003238
# ====> Epoch: 690 reconst loss: 0.0002025
# ====> Epoch: 690 kl loss: 6.0668015
# ====> Epoch: 690 elbo loss: 0.0003348
# ====> Epoch: 690 reconst loss: 0.0002176
# ====> Epoch: 690 kl loss: 5.8591399
# time loss 158:42
# ====> Epoch: 700 elbo loss: 0.0003417
# ====> Epoch: 700 reconst loss: 0.0002188
# ====> Epoch: 700 kl loss: 6.1460948
# ====> Epoch: 700 elbo loss: 0.0003442
# ====> Epoch: 700 reconst loss: 0.0002261
# ====> Epoch: 700 kl loss: 5.9062767
# time loss 161:26
# ====> Epoch: 710 elbo loss: 0.0003187
# ====> Epoch: 710 reconst loss: 0.0002032
# ====> Epoch: 710 kl loss: 5.7758899
# ====> Epoch: 710 elbo loss: 0.0003271
# ====> Epoch: 710 reconst loss: 0.0002117
# ====> Epoch: 710 kl loss: 5.7735119
# time loss 164:9
# ====> Epoch: 720 elbo loss: 0.0003054
# ====> Epoch: 720 reconst loss: 0.0001911
# ====> Epoch: 720 kl loss: 5.7133603
# ====> Epoch: 720 elbo loss: 0.0003632
# ====> Epoch: 720 reconst loss: 0.0002383
# ====> Epoch: 720 kl loss: 6.2432466
# time loss 166:52
# ====> Epoch: 730 elbo loss: 0.0003333
# ====> Epoch: 730 reconst loss: 0.0002112
# ====> Epoch: 730 kl loss: 6.1068797
# ====> Epoch: 730 elbo loss: 0.0003553
# ====> Epoch: 730 reconst loss: 0.0002349
# ====> Epoch: 730 kl loss: 6.0199518
# time loss 169:35
# ====> Epoch: 740 elbo loss: 0.0003518
# ====> Epoch: 740 reconst loss: 0.0002310
# ====> Epoch: 740 kl loss: 6.0404887
# ====> Epoch: 740 elbo loss: 0.0003364
# ====> Epoch: 740 reconst loss: 0.0002213
# ====> Epoch: 740 kl loss: 5.7543736
# time loss 172:18
# ====> Epoch: 750 elbo loss: 0.0003408
# ====> Epoch: 750 reconst loss: 0.0002210
# ====> Epoch: 750 kl loss: 5.9897494
# ====> Epoch: 750 elbo loss: 0.0003314
# ====> Epoch: 750 reconst loss: 0.0002113
# ====> Epoch: 750 kl loss: 6.0064459
# time loss 175:2
# ====> Epoch: 760 elbo loss: 0.0003527
# ====> Epoch: 760 reconst loss: 0.0002275
# ====> Epoch: 760 kl loss: 6.2583261
# ====> Epoch: 760 elbo loss: 0.0003340
# ====> Epoch: 760 reconst loss: 0.0002178
# ====> Epoch: 760 kl loss: 5.8087301
# time loss 177:45
# ====> Epoch: 770 elbo loss: 0.0003363
# ====> Epoch: 770 reconst loss: 0.0002122
# ====> Epoch: 770 kl loss: 6.2056127
# ====> Epoch: 770 elbo loss: 0.0003558
# ====> Epoch: 770 reconst loss: 0.0002370
# ====> Epoch: 770 kl loss: 5.9377027
# time loss 180:28
# ====> Epoch: 780 elbo loss: 0.0003198
# ====> Epoch: 780 reconst loss: 0.0001993
# ====> Epoch: 780 kl loss: 6.0260978
# ====> Epoch: 780 elbo loss: 0.0003490
# ====> Epoch: 780 reconst loss: 0.0002305
# ====> Epoch: 780 kl loss: 5.9246359
# time loss 183:11
# ====> Epoch: 790 elbo loss: 0.0003173
# ====> Epoch: 790 reconst loss: 0.0001941
# ====> Epoch: 790 kl loss: 6.1578650
# ====> Epoch: 790 elbo loss: 0.0003483
# ====> Epoch: 790 reconst loss: 0.0002308
# ====> Epoch: 790 kl loss: 5.8740087
# time loss 185:55
# ====> Epoch: 800 elbo loss: 0.0003311
# ====> Epoch: 800 reconst loss: 0.0002044
# ====> Epoch: 800 kl loss: 6.3372922
# ====> Epoch: 800 elbo loss: 0.0003363
# ====> Epoch: 800 reconst loss: 0.0002189
# ====> Epoch: 800 kl loss: 5.8699470
# time loss 188:38
# ====> Epoch: 810 elbo loss: 0.0003235
# ====> Epoch: 810 reconst loss: 0.0002029
# ====> Epoch: 810 kl loss: 6.0303669
# ====> Epoch: 810 elbo loss: 0.0003461
# ====> Epoch: 810 reconst loss: 0.0002246
# ====> Epoch: 810 kl loss: 6.0717492
# time loss 191:21
# ====> Epoch: 820 elbo loss: 0.0003048
# ====> Epoch: 820 reconst loss: 0.0001916
# ====> Epoch: 820 kl loss: 5.6583605
# ====> Epoch: 820 elbo loss: 0.0003271
# ====> Epoch: 820 reconst loss: 0.0002158
# ====> Epoch: 820 kl loss: 5.5658460
# time loss 194:4
# ====> Epoch: 830 elbo loss: 0.0003112
# ====> Epoch: 830 reconst loss: 0.0001917
# ====> Epoch: 830 kl loss: 5.9790721
# ====> Epoch: 830 elbo loss: 0.0003277
# ====> Epoch: 830 reconst loss: 0.0002107
# ====> Epoch: 830 kl loss: 5.8525991
# time loss 196:47
# ====> Epoch: 840 elbo loss: 0.0003212
# ====> Epoch: 840 reconst loss: 0.0002003
# ====> Epoch: 840 kl loss: 6.0457592
# ====> Epoch: 840 elbo loss: 0.0003652
# ====> Epoch: 840 reconst loss: 0.0002417
# ====> Epoch: 840 kl loss: 6.1759691
# time loss 199:31
# ====> Epoch: 850 elbo loss: 0.0003036
# ====> Epoch: 850 reconst loss: 0.0001850
# ====> Epoch: 850 kl loss: 5.9271445
# ====> Epoch: 850 elbo loss: 0.0003438
# ====> Epoch: 850 reconst loss: 0.0002247
# ====> Epoch: 850 kl loss: 5.9591370
# time loss 202:14
# ====> Epoch: 860 elbo loss: 0.0003125
# ====> Epoch: 860 reconst loss: 0.0001969
# ====> Epoch: 860 kl loss: 5.7813745
# ====> Epoch: 860 elbo loss: 0.0003359
# ====> Epoch: 860 reconst loss: 0.0002169
# ====> Epoch: 860 kl loss: 5.9495440
# time loss 204:57
# ====> Epoch: 870 elbo loss: 0.0003119
# ====> Epoch: 870 reconst loss: 0.0001920
# ====> Epoch: 870 kl loss: 5.9946213
# ====> Epoch: 870 elbo loss: 0.0003643
# ====> Epoch: 870 reconst loss: 0.0002429
# ====> Epoch: 870 kl loss: 6.0679417
# time loss 207:40
# ====> Epoch: 880 elbo loss: 0.0003220
# ====> Epoch: 880 reconst loss: 0.0002012
# ====> Epoch: 880 kl loss: 6.0355606
# ====> Epoch: 880 elbo loss: 0.0003346
# ====> Epoch: 880 reconst loss: 0.0002187
# ====> Epoch: 880 kl loss: 5.7957349
# time loss 210:23
# ====> Epoch: 890 elbo loss: 0.0003203
# ====> Epoch: 890 reconst loss: 0.0001979
# ====> Epoch: 890 kl loss: 6.1219249
# ====> Epoch: 890 elbo loss: 0.0003624
# ====> Epoch: 890 reconst loss: 0.0002474
# ====> Epoch: 890 kl loss: 5.7479486
# time loss 213:7
# ====> Epoch: 900 elbo loss: 0.0003223
# ====> Epoch: 900 reconst loss: 0.0002102
# ====> Epoch: 900 kl loss: 5.6017923
# ====> Epoch: 900 elbo loss: 0.0003409
# ====> Epoch: 900 reconst loss: 0.0002208
# ====> Epoch: 900 kl loss: 6.0027223
# time loss 215:50
# ====> Epoch: 910 elbo loss: 0.0003315
# ====> Epoch: 910 reconst loss: 0.0002098
# ====> Epoch: 910 kl loss: 6.0858097
# ====> Epoch: 910 elbo loss: 0.0003457
# ====> Epoch: 910 reconst loss: 0.0002263
# ====> Epoch: 910 kl loss: 5.9710264
# time loss 218:33
# ====> Epoch: 920 elbo loss: 0.0003308
# ====> Epoch: 920 reconst loss: 0.0002092
# ====> Epoch: 920 kl loss: 6.0811300
# ====> Epoch: 920 elbo loss: 0.0003695
# ====> Epoch: 920 reconst loss: 0.0002474
# ====> Epoch: 920 kl loss: 6.1042209
# time loss 221:16
# ====> Epoch: 930 elbo loss: 0.0003241
# ====> Epoch: 930 reconst loss: 0.0002013
# ====> Epoch: 930 kl loss: 6.1391363
# ====> Epoch: 930 elbo loss: 0.0003557
# ====> Epoch: 930 reconst loss: 0.0002329
# ====> Epoch: 930 kl loss: 6.1406231
# time loss 223:59
# ====> Epoch: 940 elbo loss: 0.0003402
# ====> Epoch: 940 reconst loss: 0.0002136
# ====> Epoch: 940 kl loss: 6.3275232
# ====> Epoch: 940 elbo loss: 0.0003459
# ====> Epoch: 940 reconst loss: 0.0002267
# ====> Epoch: 940 kl loss: 5.9618583
# time loss 226:43
# ====> Epoch: 950 elbo loss: 0.0003194
# ====> Epoch: 950 reconst loss: 0.0001948
# ====> Epoch: 950 kl loss: 6.2311950
# ====> Epoch: 950 elbo loss: 0.0003500
# ====> Epoch: 950 reconst loss: 0.0002287
# ====> Epoch: 950 kl loss: 6.0648332
# time loss 229:26
# ====> Epoch: 960 elbo loss: 0.0003172
# ====> Epoch: 960 reconst loss: 0.0001936
# ====> Epoch: 960 kl loss: 6.1821012
# ====> Epoch: 960 elbo loss: 0.0003342
# ====> Epoch: 960 reconst loss: 0.0002140
# ====> Epoch: 960 kl loss: 6.0103292
# time loss 232:9
# ====> Epoch: 970 elbo loss: 0.0003278
# ====> Epoch: 970 reconst loss: 0.0002053
# ====> Epoch: 970 kl loss: 6.1217961
# ====> Epoch: 970 elbo loss: 0.0003293
# ====> Epoch: 970 reconst loss: 0.0002119
# ====> Epoch: 970 kl loss: 5.8693466
# time loss 234:52
# ====> Epoch: 980 elbo loss: 0.0003184
# ====> Epoch: 980 reconst loss: 0.0001943
# ====> Epoch: 980 kl loss: 6.2025537
# ====> Epoch: 980 elbo loss: 0.0003605
# ====> Epoch: 980 reconst loss: 0.0002390
# ====> Epoch: 980 kl loss: 6.0733261
# time loss 237:36
# ====> Epoch: 990 elbo loss: 0.0003333
# ====> Epoch: 990 reconst loss: 0.0002050
# ====> Epoch: 990 kl loss: 6.4167643
# ====> Epoch: 990 elbo loss: 0.0003343
# ====> Epoch: 990 reconst loss: 0.0002136
# ====> Epoch: 990 kl loss: 6.0386100
# time loss 240:19
# ====> Epoch: 1000 elbo loss: 0.0003208
# ====> Epoch: 1000 reconst loss: 0.0001990
# ====> Epoch: 1000 kl loss: 6.0880527
# ====> Epoch: 1000 elbo loss: 0.0003523
# ====> Epoch: 1000 reconst loss: 0.0002282
# ====> Epoch: 1000 kl loss: 6.2051611
# time loss 243:2
# ====> Epoch: 1010 elbo loss: 0.0003316
# ====> Epoch: 1010 reconst loss: 0.0002087
# ====> Epoch: 1010 kl loss: 6.1447120
# ====> Epoch: 1010 elbo loss: 0.0003374
# ====> Epoch: 1010 reconst loss: 0.0002198
# ====> Epoch: 1010 kl loss: 5.8819113
# time loss 245:45
# ====> Epoch: 1020 elbo loss: 0.0003368
# ====> Epoch: 1020 reconst loss: 0.0002099
# ====> Epoch: 1020 kl loss: 6.3460131
# ====> Epoch: 1020 elbo loss: 0.0003659
# ====> Epoch: 1020 reconst loss: 0.0002474
# ====> Epoch: 1020 kl loss: 5.9259067
# time loss 248:28
# ====> Epoch: 1030 elbo loss: 0.0003315
# ====> Epoch: 1030 reconst loss: 0.0002081
# ====> Epoch: 1030 kl loss: 6.1722264
# ====> Epoch: 1030 elbo loss: 0.0003739
# ====> Epoch: 1030 reconst loss: 0.0002492
# ====> Epoch: 1030 kl loss: 6.2353525
# time loss 251:11
# ====> Epoch: 1040 elbo loss: 0.0003444
# ====> Epoch: 1040 reconst loss: 0.0002183
# ====> Epoch: 1040 kl loss: 6.3091760
# ====> Epoch: 1040 elbo loss: 0.0003497
# ====> Epoch: 1040 reconst loss: 0.0002296
# ====> Epoch: 1040 kl loss: 6.0054035
# time loss 253:54
# ====> Epoch: 1050 elbo loss: 0.0003380
# ====> Epoch: 1050 reconst loss: 0.0002131
# ====> Epoch: 1050 kl loss: 6.2433324
# ====> Epoch: 1050 elbo loss: 0.0003289
# ====> Epoch: 1050 reconst loss: 0.0002112
# ====> Epoch: 1050 kl loss: 5.8852348
# time loss 256:38
# ====> Epoch: 1060 elbo loss: 0.0003289
# ====> Epoch: 1060 reconst loss: 0.0002125
# ====> Epoch: 1060 kl loss: 5.8200965
# ====> Epoch: 1060 elbo loss: 0.0003605
# ====> Epoch: 1060 reconst loss: 0.0002357
# ====> Epoch: 1060 kl loss: 6.2381253
# time loss 259:21
# ====> Epoch: 1070 elbo loss: 0.0003456
# ====> Epoch: 1070 reconst loss: 0.0002195
# ====> Epoch: 1070 kl loss: 6.3060989
# ====> Epoch: 1070 elbo loss: 0.0003502
# ====> Epoch: 1070 reconst loss: 0.0002349
# ====> Epoch: 1070 kl loss: 5.7633061
# time loss 262:4
# ====> Epoch: 1080 elbo loss: 0.0003523
# ====> Epoch: 1080 reconst loss: 0.0002268
# ====> Epoch: 1080 kl loss: 6.2736492
# ====> Epoch: 1080 elbo loss: 0.0003541
# ====> Epoch: 1080 reconst loss: 0.0002375
# ====> Epoch: 1080 kl loss: 5.8322763
# time loss 264:47
# ====> Epoch: 1090 elbo loss: 0.0003253
# ====> Epoch: 1090 reconst loss: 0.0002047
# ====> Epoch: 1090 kl loss: 6.0309739
# ====> Epoch: 1090 elbo loss: 0.0003507
# ====> Epoch: 1090 reconst loss: 0.0002272
# ====> Epoch: 1090 kl loss: 6.1731896
# time loss 267:31
# ====> Epoch: 1100 elbo loss: 0.0003375
# ====> Epoch: 1100 reconst loss: 0.0002129
# ====> Epoch: 1100 kl loss: 6.2279906
# ====> Epoch: 1100 elbo loss: 0.0003501
# ====> Epoch: 1100 reconst loss: 0.0002283
# ====> Epoch: 1100 kl loss: 6.0895200
# time loss 270:14
# ====> Epoch: 1110 elbo loss: 0.0003277
# ====> Epoch: 1110 reconst loss: 0.0002048
# ====> Epoch: 1110 kl loss: 6.1457176
# ====> Epoch: 1110 elbo loss: 0.0003808
# ====> Epoch: 1110 reconst loss: 0.0002538
# ====> Epoch: 1110 kl loss: 6.3544431
# time loss 272:57
# ====> Epoch: 1120 elbo loss: 0.0003064
# ====> Epoch: 1120 reconst loss: 0.0001864
# ====> Epoch: 1120 kl loss: 6.0018702
# ====> Epoch: 1120 elbo loss: 0.0003573
# ====> Epoch: 1120 reconst loss: 0.0002359
# ====> Epoch: 1120 kl loss: 6.0691967
# time loss 275:40
# ====> Epoch: 1130 elbo loss: 0.0003163
# ====> Epoch: 1130 reconst loss: 0.0002010
# ====> Epoch: 1130 kl loss: 5.7693982
# ====> Epoch: 1130 elbo loss: 0.0003334
# ====> Epoch: 1130 reconst loss: 0.0002118
# ====> Epoch: 1130 kl loss: 6.0806503
# time loss 278:24
# ====> Epoch: 1140 elbo loss: 0.0003515
# ====> Epoch: 1140 reconst loss: 0.0002257
# ====> Epoch: 1140 kl loss: 6.2922544
# ====> Epoch: 1140 elbo loss: 0.0003696
# ====> Epoch: 1140 reconst loss: 0.0002466
# ====> Epoch: 1140 kl loss: 6.1507711
# time loss 281:7
# ====> Epoch: 1150 elbo loss: 0.0003330
# ====> Epoch: 1150 reconst loss: 0.0002047
# ====> Epoch: 1150 kl loss: 6.4144068
# ====> Epoch: 1150 elbo loss: 0.0003414
# ====> Epoch: 1150 reconst loss: 0.0002220
# ====> Epoch: 1150 kl loss: 5.9696612
# time loss 283:50
# ====> Epoch: 1160 elbo loss: 0.0003495
# ====> Epoch: 1160 reconst loss: 0.0002208
# ====> Epoch: 1160 kl loss: 6.4386516
# ====> Epoch: 1160 elbo loss: 0.0003465
# ====> Epoch: 1160 reconst loss: 0.0002263
# ====> Epoch: 1160 kl loss: 6.0098257
# time loss 286:33
# ====> Epoch: 1170 elbo loss: 0.0003243
# ====> Epoch: 1170 reconst loss: 0.0002070
# ====> Epoch: 1170 kl loss: 5.8682270
# ====> Epoch: 1170 elbo loss: 0.0003862
# ====> Epoch: 1170 reconst loss: 0.0002596
# ====> Epoch: 1170 kl loss: 6.3313360
# time loss 289:16
# ====> Epoch: 1180 elbo loss: 0.0003249
# ====> Epoch: 1180 reconst loss: 0.0002047
# ====> Epoch: 1180 kl loss: 6.0104327
# ====> Epoch: 1180 elbo loss: 0.0003359
# ====> Epoch: 1180 reconst loss: 0.0002157
# ====> Epoch: 1180 kl loss: 6.0132675
# time loss 291:59
# ====> Epoch: 1190 elbo loss: 0.0003225
# ====> Epoch: 1190 reconst loss: 0.0001986
# ====> Epoch: 1190 kl loss: 6.1978021
# ====> Epoch: 1190 elbo loss: 0.0003507
# ====> Epoch: 1190 reconst loss: 0.0002299
# ====> Epoch: 1190 kl loss: 6.0428486
# time loss 294:43
# ====> Epoch: 1200 elbo loss: 0.0003361
# ====> Epoch: 1200 reconst loss: 0.0002107
# ====> Epoch: 1200 kl loss: 6.2704124
# ====> Epoch: 1200 elbo loss: 0.0003550
# ====> Epoch: 1200 reconst loss: 0.0002329
# ====> Epoch: 1200 kl loss: 6.1041183
# time loss 297:26
# ====> Epoch: 1210 elbo loss: 0.0003327
# ====> Epoch: 1210 reconst loss: 0.0002109
# ====> Epoch: 1210 kl loss: 6.0856724
# ====> Epoch: 1210 elbo loss: 0.0003558
# ====> Epoch: 1210 reconst loss: 0.0002347
# ====> Epoch: 1210 kl loss: 6.0535417
# time loss 300:9
# ====> Epoch: 1220 elbo loss: 0.0003404
# ====> Epoch: 1220 reconst loss: 0.0002135
# ====> Epoch: 1220 kl loss: 6.3420873
# ====> Epoch: 1220 elbo loss: 0.0003412
# ====> Epoch: 1220 reconst loss: 0.0002219
# ====> Epoch: 1220 kl loss: 5.9643016
# time loss 302:52
# ====> Epoch: 1230 elbo loss: 0.0003336
# ====> Epoch: 1230 reconst loss: 0.0002066
# ====> Epoch: 1230 kl loss: 6.3528004
# ====> Epoch: 1230 elbo loss: 0.0003620
# ====> Epoch: 1230 reconst loss: 0.0002424
# ====> Epoch: 1230 kl loss: 5.9787388
# time loss 305:36
# ====> Epoch: 1240 elbo loss: 0.0003337
# ====> Epoch: 1240 reconst loss: 0.0002103
# ====> Epoch: 1240 kl loss: 6.1694975
# ====> Epoch: 1240 elbo loss: 0.0003732
# ====> Epoch: 1240 reconst loss: 0.0002474
# ====> Epoch: 1240 kl loss: 6.2863121
# time loss 308:19
# ====> Epoch: 1250 elbo loss: 0.0003123
# ====> Epoch: 1250 reconst loss: 0.0001977
# ====> Epoch: 1250 kl loss: 5.7311802
# ====> Epoch: 1250 elbo loss: 0.0003601
# ====> Epoch: 1250 reconst loss: 0.0002400
# ====> Epoch: 1250 kl loss: 6.0075593
# time loss 311:2
# ====> Epoch: 1260 elbo loss: 0.0003223
# ====> Epoch: 1260 reconst loss: 0.0002036
# ====> Epoch: 1260 kl loss: 5.9319968
# ====> Epoch: 1260 elbo loss: 0.0003440
# ====> Epoch: 1260 reconst loss: 0.0002255
# ====> Epoch: 1260 kl loss: 5.9249840
# time loss 313:45
# ====> Epoch: 1270 elbo loss: 0.0003176
# ====> Epoch: 1270 reconst loss: 0.0001913
# ====> Epoch: 1270 kl loss: 6.3194742
# ====> Epoch: 1270 elbo loss: 0.0003696
# ====> Epoch: 1270 reconst loss: 0.0002469
# ====> Epoch: 1270 kl loss: 6.1354804
# time loss 316:28
# ====> Epoch: 1280 elbo loss: 0.0003204
# ====> Epoch: 1280 reconst loss: 0.0001920
# ====> Epoch: 1280 kl loss: 6.4214573
# ====> Epoch: 1280 elbo loss: 0.0003253
# ====> Epoch: 1280 reconst loss: 0.0002123
# ====> Epoch: 1280 kl loss: 5.6539598
# time loss 319:12
# ====> Epoch: 1290 elbo loss: 0.0003296
# ====> Epoch: 1290 reconst loss: 0.0002070
# ====> Epoch: 1290 kl loss: 6.1292820
# ====> Epoch: 1290 elbo loss: 0.0003522
# ====> Epoch: 1290 reconst loss: 0.0002279
# ====> Epoch: 1290 kl loss: 6.2175102
# time loss 321:55
# ====> Epoch: 1300 elbo loss: 0.0003074
# ====> Epoch: 1300 reconst loss: 0.0001850
# ====> Epoch: 1300 kl loss: 6.1189227
# ====> Epoch: 1300 elbo loss: 0.0003490
# ====> Epoch: 1300 reconst loss: 0.0002287
# ====> Epoch: 1300 kl loss: 6.0131493
# time loss 324:38
# ====> Epoch: 1310 elbo loss: 0.0003157
# ====> Epoch: 1310 reconst loss: 0.0001959
# ====> Epoch: 1310 kl loss: 5.9920068
# ====> Epoch: 1310 elbo loss: 0.0003610
# ====> Epoch: 1310 reconst loss: 0.0002396
# ====> Epoch: 1310 kl loss: 6.0694871
# time loss 327:21
# ====> Epoch: 1320 elbo loss: 0.0003115
# ====> Epoch: 1320 reconst loss: 0.0001925
# ====> Epoch: 1320 kl loss: 5.9537525
# ====> Epoch: 1320 elbo loss: 0.0003437
# ====> Epoch: 1320 reconst loss: 0.0002191
# ====> Epoch: 1320 kl loss: 6.2296906
# time loss 330:4
# ====> Epoch: 1330 elbo loss: 0.0003355
# ====> Epoch: 1330 reconst loss: 0.0002140
# ====> Epoch: 1330 kl loss: 6.0737729
# ====> Epoch: 1330 elbo loss: 0.0003468
# ====> Epoch: 1330 reconst loss: 0.0002268
# ====> Epoch: 1330 kl loss: 6.0018430
# time loss 332:48
# ====> Epoch: 1340 elbo loss: 0.0003565
# ====> Epoch: 1340 reconst loss: 0.0002242
# ====> Epoch: 1340 kl loss: 6.6155419
# ====> Epoch: 1340 elbo loss: 0.0003626
# ====> Epoch: 1340 reconst loss: 0.0002373
# ====> Epoch: 1340 kl loss: 6.2643433
# time loss 335:31
# ====> Epoch: 1350 elbo loss: 0.0003229
# ====> Epoch: 1350 reconst loss: 0.0001986
# ====> Epoch: 1350 kl loss: 6.2154264
# ====> Epoch: 1350 elbo loss: 0.0003563
# ====> Epoch: 1350 reconst loss: 0.0002358
# ====> Epoch: 1350 kl loss: 6.0259433
# time loss 338:14
# ====> Epoch: 1360 elbo loss: 0.0003290
# ====> Epoch: 1360 reconst loss: 0.0002024
# ====> Epoch: 1360 kl loss: 6.3251519
# ====> Epoch: 1360 elbo loss: 0.0003576
# ====> Epoch: 1360 reconst loss: 0.0002303
# ====> Epoch: 1360 kl loss: 6.3671379
# time loss 340:57
# ====> Epoch: 1370 elbo loss: 0.0003282
# ====> Epoch: 1370 reconst loss: 0.0002002
# ====> Epoch: 1370 kl loss: 6.4000974
# ====> Epoch: 1370 elbo loss: 0.0003781
# ====> Epoch: 1370 reconst loss: 0.0002506
# ====> Epoch: 1370 kl loss: 6.3753753
# time loss 343:40
# ====> Epoch: 1380 elbo loss: 0.0003442
# ====> Epoch: 1380 reconst loss: 0.0002224
# ====> Epoch: 1380 kl loss: 6.0888343
# ====> Epoch: 1380 elbo loss: 0.0003772
# ====> Epoch: 1380 reconst loss: 0.0002459
# ====> Epoch: 1380 kl loss: 6.5628161
# time loss 346:23
# ====> Epoch: 1390 elbo loss: 0.0003121
# ====> Epoch: 1390 reconst loss: 0.0001878
# ====> Epoch: 1390 kl loss: 6.2128992
# ====> Epoch: 1390 elbo loss: 0.0003343
# ====> Epoch: 1390 reconst loss: 0.0002105
# ====> Epoch: 1390 kl loss: 6.1891637
# time loss 349:6
# ====> Epoch: 1400 elbo loss: 0.0003168
# ====> Epoch: 1400 reconst loss: 0.0001904
# ====> Epoch: 1400 kl loss: 6.3212695
# ====> Epoch: 1400 elbo loss: 0.0003393
# ====> Epoch: 1400 reconst loss: 0.0002234
# ====> Epoch: 1400 kl loss: 5.7931757
# time loss 351:50
# ====> Epoch: 1410 elbo loss: 0.0003390
# ====> Epoch: 1410 reconst loss: 0.0002138
# ====> Epoch: 1410 kl loss: 6.2599969
# ====> Epoch: 1410 elbo loss: 0.0003448
# ====> Epoch: 1410 reconst loss: 0.0002309
# ====> Epoch: 1410 kl loss: 5.6976085
# time loss 354:33
# ====> Epoch: 1420 elbo loss: 0.0003438
# ====> Epoch: 1420 reconst loss: 0.0002192
# ====> Epoch: 1420 kl loss: 6.2296228
# ====> Epoch: 1420 elbo loss: 0.0003409
# ====> Epoch: 1420 reconst loss: 0.0002184
# ====> Epoch: 1420 kl loss: 6.1230340
# time loss 357:16
# ====> Epoch: 1430 elbo loss: 0.0003173
# ====> Epoch: 1430 reconst loss: 0.0001916
# ====> Epoch: 1430 kl loss: 6.2863793
# ====> Epoch: 1430 elbo loss: 0.0003434
# ====> Epoch: 1430 reconst loss: 0.0002214
# ====> Epoch: 1430 kl loss: 6.0985022
# time loss 359:59
# ====> Epoch: 1440 elbo loss: 0.0003284
# ====> Epoch: 1440 reconst loss: 0.0002015
# ====> Epoch: 1440 kl loss: 6.3475718
# ====> Epoch: 1440 elbo loss: 0.0003645
# ====> Epoch: 1440 reconst loss: 0.0002433
# ====> Epoch: 1440 kl loss: 6.0596323
# time loss 362:43
# ====> Epoch: 1450 elbo loss: 0.0003132
# ====> Epoch: 1450 reconst loss: 0.0001920
# ====> Epoch: 1450 kl loss: 6.0608482
# ====> Epoch: 1450 elbo loss: 0.0003338
# ====> Epoch: 1450 reconst loss: 0.0002115
# ====> Epoch: 1450 kl loss: 6.1150074
# time loss 365:26
# ====> Epoch: 1460 elbo loss: 0.0003234
# ====> Epoch: 1460 reconst loss: 0.0002044
# ====> Epoch: 1460 kl loss: 5.9486227
# ====> Epoch: 1460 elbo loss: 0.0003607
# ====> Epoch: 1460 reconst loss: 0.0002333
# ====> Epoch: 1460 kl loss: 6.3704710
# time loss 368:9
# ====> Epoch: 1470 elbo loss: 0.0003211
# ====> Epoch: 1470 reconst loss: 0.0001995
# ====> Epoch: 1470 kl loss: 6.0823669
# ====> Epoch: 1470 elbo loss: 0.0003634
# ====> Epoch: 1470 reconst loss: 0.0002388
# ====> Epoch: 1470 kl loss: 6.2301307
# time loss 370:52
# ====> Epoch: 1480 elbo loss: 0.0003361
# ====> Epoch: 1480 reconst loss: 0.0002078
# ====> Epoch: 1480 kl loss: 6.4154162
# ====> Epoch: 1480 elbo loss: 0.0003567
# ====> Epoch: 1480 reconst loss: 0.0002367
# ====> Epoch: 1480 kl loss: 6.0006590
# time loss 373:35
# ====> Epoch: 1490 elbo loss: 0.0003341
# ====> Epoch: 1490 reconst loss: 0.0002054
# ====> Epoch: 1490 kl loss: 6.4342585
# ====> Epoch: 1490 elbo loss: 0.0003430
# ====> Epoch: 1490 reconst loss: 0.0002230
# ====> Epoch: 1490 kl loss: 6.0009727
# time loss 376:19
# ====> Epoch: 1500 elbo loss: 0.0003293
# ====> Epoch: 1500 reconst loss: 0.0002015
# ====> Epoch: 1500 kl loss: 6.3892188
# ====> Epoch: 1500 elbo loss: 0.0003641
# ====> Epoch: 1500 reconst loss: 0.0002386
# ====> Epoch: 1500 kl loss: 6.2759690
# time loss 379:2
# ====> Epoch: 1510 elbo loss: 0.0003338
# ====> Epoch: 1510 reconst loss: 0.0002029
# ====> Epoch: 1510 kl loss: 6.5454798
# ====> Epoch: 1510 elbo loss: 0.0003303
# ====> Epoch: 1510 reconst loss: 0.0002174
# ====> Epoch: 1510 kl loss: 5.6460166
# time loss 381:45
# ====> Epoch: 1520 elbo loss: 0.0003247
# ====> Epoch: 1520 reconst loss: 0.0001970
# ====> Epoch: 1520 kl loss: 6.3888049
# ====> Epoch: 1520 elbo loss: 0.0003508
# ====> Epoch: 1520 reconst loss: 0.0002267
# ====> Epoch: 1520 kl loss: 6.2046971
# time loss 384:28
# ====> Epoch: 1530 elbo loss: 0.0003379
# ====> Epoch: 1530 reconst loss: 0.0002141
# ====> Epoch: 1530 kl loss: 6.1893134
# ====> Epoch: 1530 elbo loss: 0.0003390
# ====> Epoch: 1530 reconst loss: 0.0002185
# ====> Epoch: 1530 kl loss: 6.0271263
# time loss 387:11
# ====> Epoch: 1540 elbo loss: 0.0003316
# ====> Epoch: 1540 reconst loss: 0.0002063
# ====> Epoch: 1540 kl loss: 6.2626734
# ====> Epoch: 1540 elbo loss: 0.0003522
# ====> Epoch: 1540 reconst loss: 0.0002315
# ====> Epoch: 1540 kl loss: 6.0335336
# time loss 389:55
# ====> Epoch: 1550 elbo loss: 0.0003345
# ====> Epoch: 1550 reconst loss: 0.0002037
# ====> Epoch: 1550 kl loss: 6.5410504
# ====> Epoch: 1550 elbo loss: 0.0003384
# ====> Epoch: 1550 reconst loss: 0.0002211
# ====> Epoch: 1550 kl loss: 5.8632684
# time loss 392:38
# ====> Epoch: 1560 elbo loss: 0.0003350
# ====> Epoch: 1560 reconst loss: 0.0002092
# ====> Epoch: 1560 kl loss: 6.2934632
# ====> Epoch: 1560 elbo loss: 0.0003508
# ====> Epoch: 1560 reconst loss: 0.0002304
# ====> Epoch: 1560 kl loss: 6.0215220
# time loss 395:21
# ====> Epoch: 1570 elbo loss: 0.0003461
# ====> Epoch: 1570 reconst loss: 0.0002212
# ====> Epoch: 1570 kl loss: 6.2445798
# ====> Epoch: 1570 elbo loss: 0.0003838
# ====> Epoch: 1570 reconst loss: 0.0002560
# ====> Epoch: 1570 kl loss: 6.3941073
# time loss 398:4
# ====> Epoch: 1580 elbo loss: 0.0003379
# ====> Epoch: 1580 reconst loss: 0.0002088
# ====> Epoch: 1580 kl loss: 6.4521389
# ====> Epoch: 1580 elbo loss: 0.0003728
# ====> Epoch: 1580 reconst loss: 0.0002499
# ====> Epoch: 1580 kl loss: 6.1488953
# time loss 400:47
# ====> Epoch: 1590 elbo loss: 0.0003164
# ====> Epoch: 1590 reconst loss: 0.0001961
# ====> Epoch: 1590 kl loss: 6.0169034
# ====> Epoch: 1590 elbo loss: 0.0003401
# ====> Epoch: 1590 reconst loss: 0.0002199
# ====> Epoch: 1590 kl loss: 6.0071812
# time loss 403:31
# ====> Epoch: 1600 elbo loss: 0.0003258
# ====> Epoch: 1600 reconst loss: 0.0002048
# ====> Epoch: 1600 kl loss: 6.0517478
# ====> Epoch: 1600 elbo loss: 0.0003470
# ====> Epoch: 1600 reconst loss: 0.0002267
# ====> Epoch: 1600 kl loss: 6.0167699
# time loss 406:14
# ====> Epoch: 1610 elbo loss: 0.0003268
# ====> Epoch: 1610 reconst loss: 0.0002025
# ====> Epoch: 1610 kl loss: 6.2145019
# ====> Epoch: 1610 elbo loss: 0.0003364
# ====> Epoch: 1610 reconst loss: 0.0002173
# ====> Epoch: 1610 kl loss: 5.9571371
# time loss 408:57
# ====> Epoch: 1620 elbo loss: 0.0003176
# ====> Epoch: 1620 reconst loss: 0.0001926
# ====> Epoch: 1620 kl loss: 6.2528558
# ====> Epoch: 1620 elbo loss: 0.0003445
# ====> Epoch: 1620 reconst loss: 0.0002230
# ====> Epoch: 1620 kl loss: 6.0788074
# time loss 411:40
# ====> Epoch: 1630 elbo loss: 0.0003095
# ====> Epoch: 1630 reconst loss: 0.0001878
# ====> Epoch: 1630 kl loss: 6.0825024
# ====> Epoch: 1630 elbo loss: 0.0003526
# ====> Epoch: 1630 reconst loss: 0.0002259
# ====> Epoch: 1630 kl loss: 6.3348570
# time loss 414:23
# ====> Epoch: 1640 elbo loss: 0.0003400
# ====> Epoch: 1640 reconst loss: 0.0002093
# ====> Epoch: 1640 kl loss: 6.5363202
# ====> Epoch: 1640 elbo loss: 0.0003458
# ====> Epoch: 1640 reconst loss: 0.0002218
# ====> Epoch: 1640 kl loss: 6.1989636
# time loss 417:7
# ====> Epoch: 1650 elbo loss: 0.0003303
# ====> Epoch: 1650 reconst loss: 0.0002028
# ====> Epoch: 1650 kl loss: 6.3731256
# ====> Epoch: 1650 elbo loss: 0.0003337
# ====> Epoch: 1650 reconst loss: 0.0002143
# ====> Epoch: 1650 kl loss: 5.9706798
# time loss 419:50
# ====> Epoch: 1660 elbo loss: 0.0003286
# ====> Epoch: 1660 reconst loss: 0.0001956
# ====> Epoch: 1660 kl loss: 6.6488266
# ====> Epoch: 1660 elbo loss: 0.0003408
# ====> Epoch: 1660 reconst loss: 0.0002206
# ====> Epoch: 1660 kl loss: 6.0120325
# time loss 422:33
# ====> Epoch: 1670 elbo loss: 0.0003330
# ====> Epoch: 1670 reconst loss: 0.0002045
# ====> Epoch: 1670 kl loss: 6.4249897
# ====> Epoch: 1670 elbo loss: 0.0003443
# ====> Epoch: 1670 reconst loss: 0.0002223
# ====> Epoch: 1670 kl loss: 6.1025763
# time loss 425:16
# ====> Epoch: 1680 elbo loss: 0.0003249
# ====> Epoch: 1680 reconst loss: 0.0001987
# ====> Epoch: 1680 kl loss: 6.3076348
# ====> Epoch: 1680 elbo loss: 0.0003479
# ====> Epoch: 1680 reconst loss: 0.0002293
# ====> Epoch: 1680 kl loss: 5.9326205
# time loss 427:59
# ====> Epoch: 1690 elbo loss: 0.0003143
# ====> Epoch: 1690 reconst loss: 0.0001904
# ====> Epoch: 1690 kl loss: 6.1942410
# ====> Epoch: 1690 elbo loss: 0.0003451
# ====> Epoch: 1690 reconst loss: 0.0002233
# ====> Epoch: 1690 kl loss: 6.0888619
# time loss 430:42
# ====> Epoch: 1700 elbo loss: 0.0003175
# ====> Epoch: 1700 reconst loss: 0.0001952
# ====> Epoch: 1700 kl loss: 6.1143808
# ====> Epoch: 1700 elbo loss: 0.0003275
# ====> Epoch: 1700 reconst loss: 0.0002080
# ====> Epoch: 1700 kl loss: 5.9715610
# time loss 433:25
# ====> Epoch: 1710 elbo loss: 0.0003369
# ====> Epoch: 1710 reconst loss: 0.0002121
# ====> Epoch: 1710 kl loss: 6.2387815
# ====> Epoch: 1710 elbo loss: 0.0003515
# ====> Epoch: 1710 reconst loss: 0.0002272
# ====> Epoch: 1710 kl loss: 6.2161341
# time loss 436:9
# ====> Epoch: 1720 elbo loss: 0.0003022
# ====> Epoch: 1720 reconst loss: 0.0001765
# ====> Epoch: 1720 kl loss: 6.2868133
# ====> Epoch: 1720 elbo loss: 0.0003376
# ====> Epoch: 1720 reconst loss: 0.0002158
# ====> Epoch: 1720 kl loss: 6.0872388
# time loss 438:52
# ====> Epoch: 1730 elbo loss: 0.0003202
# ====> Epoch: 1730 reconst loss: 0.0001965
# ====> Epoch: 1730 kl loss: 6.1816931
# ====> Epoch: 1730 elbo loss: 0.0003683
# ====> Epoch: 1730 reconst loss: 0.0002470
# ====> Epoch: 1730 kl loss: 6.0651579
# time loss 441:35
# ====> Epoch: 1740 elbo loss: 0.0003124
# ====> Epoch: 1740 reconst loss: 0.0001931
# ====> Epoch: 1740 kl loss: 5.9661546
# ====> Epoch: 1740 elbo loss: 0.0003342
# ====> Epoch: 1740 reconst loss: 0.0002178
# ====> Epoch: 1740 kl loss: 5.8169885
# time loss 444:18
# ====> Epoch: 1750 elbo loss: 0.0003274
# ====> Epoch: 1750 reconst loss: 0.0001990
# ====> Epoch: 1750 kl loss: 6.4216366
# ====> Epoch: 1750 elbo loss: 0.0003447
# ====> Epoch: 1750 reconst loss: 0.0002202
# ====> Epoch: 1750 kl loss: 6.2225175
# time loss 447:1
# ====> Epoch: 1760 elbo loss: 0.0003275
# ====> Epoch: 1760 reconst loss: 0.0001923
# ====> Epoch: 1760 kl loss: 6.7611485
# ====> Epoch: 1760 elbo loss: 0.0003357
# ====> Epoch: 1760 reconst loss: 0.0002153
# ====> Epoch: 1760 kl loss: 6.0210009
# time loss 449:45
# ====> Epoch: 1770 elbo loss: 0.0003147
# ====> Epoch: 1770 reconst loss: 0.0001887
# ====> Epoch: 1770 kl loss: 6.2992086
# ====> Epoch: 1770 elbo loss: 0.0003535
# ====> Epoch: 1770 reconst loss: 0.0002319
# ====> Epoch: 1770 kl loss: 6.0807934
# time loss 452:28
# ====> Epoch: 1780 elbo loss: 0.0003313
# ====> Epoch: 1780 reconst loss: 0.0002057
# ====> Epoch: 1780 kl loss: 6.2796130
# ====> Epoch: 1780 elbo loss: 0.0003326
# ====> Epoch: 1780 reconst loss: 0.0002140
# ====> Epoch: 1780 kl loss: 5.9328852
# time loss 455:11
# ====> Epoch: 1790 elbo loss: 0.0003290
# ====> Epoch: 1790 reconst loss: 0.0002082
# ====> Epoch: 1790 kl loss: 6.0433836
# ====> Epoch: 1790 elbo loss: 0.0003548
# ====> Epoch: 1790 reconst loss: 0.0002364
# ====> Epoch: 1790 kl loss: 5.9208789
# time loss 457:54
# ====> Epoch: 1800 elbo loss: 0.0003165
# ====> Epoch: 1800 reconst loss: 0.0001925
# ====> Epoch: 1800 kl loss: 6.2006211
# ====> Epoch: 1800 elbo loss: 0.0003552
# ====> Epoch: 1800 reconst loss: 0.0002277
# ====> Epoch: 1800 kl loss: 6.3737206
# time loss 460:37
# ====> Epoch: 1810 elbo loss: 0.0003166
# ====> Epoch: 1810 reconst loss: 0.0001869
# ====> Epoch: 1810 kl loss: 6.4891720
# ====> Epoch: 1810 elbo loss: 0.0003792
# ====> Epoch: 1810 reconst loss: 0.0002503
# ====> Epoch: 1810 kl loss: 6.4448261
# time loss 463:20
# ====> Epoch: 1820 elbo loss: 0.0003263
# ====> Epoch: 1820 reconst loss: 0.0001973
# ====> Epoch: 1820 kl loss: 6.4469519
# ====> Epoch: 1820 elbo loss: 0.0003837
# ====> Epoch: 1820 reconst loss: 0.0002515
# ====> Epoch: 1820 kl loss: 6.6094775
# time loss 466:3
# ====> Epoch: 1830 elbo loss: 0.0003068
# ====> Epoch: 1830 reconst loss: 0.0001841
# ====> Epoch: 1830 kl loss: 6.1316943
# ====> Epoch: 1830 elbo loss: 0.0003381
# ====> Epoch: 1830 reconst loss: 0.0002164
# ====> Epoch: 1830 kl loss: 6.0868049
# time loss 468:46
# ====> Epoch: 1840 elbo loss: 0.0003253
# ====> Epoch: 1840 reconst loss: 0.0001978
# ====> Epoch: 1840 kl loss: 6.3719025
# ====> Epoch: 1840 elbo loss: 0.0003338
# ====> Epoch: 1840 reconst loss: 0.0002122
# ====> Epoch: 1840 kl loss: 6.0802441
# time loss 471:30
# ====> Epoch: 1850 elbo loss: 0.0003219
# ====> Epoch: 1850 reconst loss: 0.0001970
# ====> Epoch: 1850 kl loss: 6.2455115
# ====> Epoch: 1850 elbo loss: 0.0003325
# ====> Epoch: 1850 reconst loss: 0.0002113
# ====> Epoch: 1850 kl loss: 6.0593357
# time loss 474:13
# ====> Epoch: 1860 elbo loss: 0.0003129
# ====> Epoch: 1860 reconst loss: 0.0001936
# ====> Epoch: 1860 kl loss: 5.9607139
# ====> Epoch: 1860 elbo loss: 0.0003379
# ====> Epoch: 1860 reconst loss: 0.0002164
# ====> Epoch: 1860 kl loss: 6.0735564
# time loss 476:56
# ====> Epoch: 1870 elbo loss: 0.0003216
# ====> Epoch: 1870 reconst loss: 0.0001961
# ====> Epoch: 1870 kl loss: 6.2785931
# ====> Epoch: 1870 elbo loss: 0.0003450
# ====> Epoch: 1870 reconst loss: 0.0002220
# ====> Epoch: 1870 kl loss: 6.1491089
# time loss 479:39
# ====> Epoch: 1880 elbo loss: 0.0003346
# ====> Epoch: 1880 reconst loss: 0.0002075
# ====> Epoch: 1880 kl loss: 6.3529239
# ====> Epoch: 1880 elbo loss: 0.0003674
# ====> Epoch: 1880 reconst loss: 0.0002417
# ====> Epoch: 1880 kl loss: 6.2822742
# time loss 482:22
# ====> Epoch: 1890 elbo loss: 0.0003346
# ====> Epoch: 1890 reconst loss: 0.0002019
# ====> Epoch: 1890 kl loss: 6.6343908
# ====> Epoch: 1890 elbo loss: 0.0003330
# ====> Epoch: 1890 reconst loss: 0.0002132
# ====> Epoch: 1890 kl loss: 5.9892721
# time loss 485:5
# ====> Epoch: 1900 elbo loss: 0.0003223
# ====> Epoch: 1900 reconst loss: 0.0001987
# ====> Epoch: 1900 kl loss: 6.1761551
# ====> Epoch: 1900 elbo loss: 0.0003551
# ====> Epoch: 1900 reconst loss: 0.0002330
# ====> Epoch: 1900 kl loss: 6.1057739
# time loss 487:48
# ====> Epoch: 1910 elbo loss: 0.0003267
# ====> Epoch: 1910 reconst loss: 0.0001979
# ====> Epoch: 1910 kl loss: 6.4358654
# ====> Epoch: 1910 elbo loss: 0.0003256
# ====> Epoch: 1910 reconst loss: 0.0002040
# ====> Epoch: 1910 kl loss: 6.0757923
# time loss 490:31
# ====> Epoch: 1920 elbo loss: 0.0003326
# ====> Epoch: 1920 reconst loss: 0.0002012
# ====> Epoch: 1920 kl loss: 6.5718188
# ====> Epoch: 1920 elbo loss: 0.0003550
# ====> Epoch: 1920 reconst loss: 0.0002316
# ====> Epoch: 1920 kl loss: 6.1732812
# time loss 493:14
# ====> Epoch: 1930 elbo loss: 0.0003211
# ====> Epoch: 1930 reconst loss: 0.0001976
# ====> Epoch: 1930 kl loss: 6.1755252
# ====> Epoch: 1930 elbo loss: 0.0003764
# ====> Epoch: 1930 reconst loss: 0.0002481
# ====> Epoch: 1930 kl loss: 6.4193258
# time loss 495:57
# ====> Epoch: 1940 elbo loss: 0.0003274
# ====> Epoch: 1940 reconst loss: 0.0001988
# ====> Epoch: 1940 kl loss: 6.4284992
# ====> Epoch: 1940 elbo loss: 0.0003533
# ====> Epoch: 1940 reconst loss: 0.0002297
# ====> Epoch: 1940 kl loss: 6.1775208
# time loss 498:40
# ====> Epoch: 1950 elbo loss: 0.0003314
# ====> Epoch: 1950 reconst loss: 0.0002040
# ====> Epoch: 1950 kl loss: 6.3700037
# ====> Epoch: 1950 elbo loss: 0.0003487
# ====> Epoch: 1950 reconst loss: 0.0002211
# ====> Epoch: 1950 kl loss: 6.3834634
# time loss 501:24
# ====> Epoch: 1960 elbo loss: 0.0003261
# ====> Epoch: 1960 reconst loss: 0.0002033
# ====> Epoch: 1960 kl loss: 6.1396070
# ====> Epoch: 1960 elbo loss: 0.0003428
# ====> Epoch: 1960 reconst loss: 0.0002227
# ====> Epoch: 1960 kl loss: 6.0078545
# time loss 504:7
# ====> Epoch: 1970 elbo loss: 0.0003356
# ====> Epoch: 1970 reconst loss: 0.0002101
# ====> Epoch: 1970 kl loss: 6.2763815
# ====> Epoch: 1970 elbo loss: 0.0003524
# ====> Epoch: 1970 reconst loss: 0.0002262
# ====> Epoch: 1970 kl loss: 6.3111558
# time loss 506:50
# ====> Epoch: 1980 elbo loss: 0.0003311
# ====> Epoch: 1980 reconst loss: 0.0002042
# ====> Epoch: 1980 kl loss: 6.3453960
# ====> Epoch: 1980 elbo loss: 0.0003475
# ====> Epoch: 1980 reconst loss: 0.0002249
# ====> Epoch: 1980 kl loss: 6.1300073
# time loss 509:33
# ====> Epoch: 1990 elbo loss: 0.0003311
# ====> Epoch: 1990 reconst loss: 0.0002076
# ====> Epoch: 1990 kl loss: 6.1737285
# ====> Epoch: 1990 elbo loss: 0.0003547
# ====> Epoch: 1990 reconst loss: 0.0002304
# ====> Epoch: 1990 kl loss: 6.2166433
# time loss 512:16
# total time loss 514:44

# %%
device = 'cpu'
model = torch.load('./vae_model.pth', map_location=device)

# %%
latent_dim = 5

# %%
import torchvision
from torchvision.utils import save_image
# Generation
w = 0
import random
with torch.no_grad():    
    
    noise = torch.randn(100, latent_dim).to(device)
    c = [i for i in range(10) for _ in range(10)]
    c = one_hot_encode(c, num_classes = num_class)
    c = torch.tensor(c).to(device)
    generated_imgs = model.decoder(noise, c)
    resized_image = torchvision.transforms.Resize((50, 50))(generated_imgs)
    save_image(resized_image, './pictures/genera.png', nrow=10)

# %%
device = 'cuda:0'
model = torch.load('./vae_model.pth', map_location=device)

# %%
latent_dim = 5

# %%
model.eval()
with torch.no_grad():
    num = 70000
    t = 100
    num0 = int(num/t)
    for i in range(t):
        noise = torch.randn(num0, latent_dim).to(device)
        label0 = torch.randint(low=0, high=10, size=(num0,), dtype=torch.int32)
        c = label0.tolist()
        c = one_hot_encode(c, num_classes = num_class)
        c = torch.tensor(c).to(device)
        x0 = model.decoder(noise, c)
        if(i == 0):
            x = x0
            label = label0
        else:
            x = torch.cat((x, x0), 0)
            label = torch.cat((label, label0), 0)

# %%
from torch.utils.data import Dataset
class CustomDataset(Dataset):
    def __init__(self, x, label):
        self.x = x
        self.label = label
        self.n = x.shape[0]

    def __len__(self):
        return self.n

    def __getitem__(self, idx):
        return self.x[idx], self.label[idx]

# %%
split_idx = 60000
train_x, train_label = x[:split_idx], label[:split_idx]
test_x, test_label = x[split_idx:], label[split_idx:]
train_dataset = CustomDataset(train_x, train_label)
test_dataset = CustomDataset(test_x, test_label)

import pickle
train_file = './data/model/train_dataset.pkl'
test_file = './data/model/test_dataset.pkl'

with open(train_file, 'wb') as f:
    pickle.dump(train_dataset, f)
with open(test_file, 'wb') as f:
    pickle.dump(test_dataset, f)

# %%
import pickle
train_file = './data/model/train_dataset.pkl'
test_file = './data/model/test_dataset.pkl'

with open(train_file, 'rb') as f:
    train_dataset = pickle.load(f)
with open(test_file, 'rb') as f:
    test_dataset = pickle.load(f)
    
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=bs, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=bs, shuffle=False)

print(len(train_dataset), len(test_dataset))
# Out:
# 60000 10000

# %%
import os
from torch.utils.data import DataLoader, Subset

num_samples = 30000
indices = np.random.choice(len(train_dataset), num_samples, replace=False)
subset_train_dataset = Subset(train_dataset, indices)

print("start deleting")
import shutil
save_dir = './samples/base'
if os.path.exists(save_dir) and os.path.isdir(save_dir):
    shutil.rmtree(save_dir)
else:
    print(f"Directory does not exist.")
print("done deleting")

os.makedirs(save_dir, exist_ok=True)

print("start saving")
def save_images(dataset, save_dir):
    for idx, (image, label) in enumerate(dataset):
        image = transforms.ToPILImage()(image)
        image.save(os.path.join(save_dir, f'image_{idx}.png'))
save_images(subset_train_dataset, save_dir)
print("done saving")
# Out:
# start deleting
# done deleting
# start saving
# done saving
